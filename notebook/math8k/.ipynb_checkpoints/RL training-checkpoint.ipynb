# %%
import random
import pandas as pd
from datasets import Dataset
import os 
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig
from datasets import load_dataset
import seaborn as sns
from datasets import load_dataset, load_from_disk
import numpy as np
import json

# %%
cd /home/al2644/research/codebase/reasoning/rlvr/
# Out:
# /home/al2644/research/codebase/reasoning/rlvr

# %%
train_df = pd.read_parquet("./data/train/math8k/train.parquet")
test_df = pd.read_parquet("./data/train/math8k/test.parquet")
cs_rl_df = pd.read_parquet("./data/train/math8k/coldstart_rl_train.parquet")

# %%
cs_rl_df
# Out:
#      data_source                                             prompt ability  \
# 0         math8k  [{'content': 'Let $a$ and $b$ be the two real ...    math
# 1         math8k  [{'content': 'For how many integer values of $...    math
# 2         math8k  [{'content': 'A car is averaging 50 miles per ...    math
# 3         math8k  [{'content': 'Find the greatest common divisor...    math
# 4         math8k  [{'content': 'An octahedron consists of two sq...    math
# ...          ...                                                ...     ...
# 5547      math8k  [{'content': 'What is the coefficient of $x^3$...    math
# 5548      math8k  [{'content': 'If $\left\lfloor n^2/4 \right\rf...    math
# 5549      math8k  [{'content': 'The diagonals of rectangle $PQRS...    math
# 5550      math8k  [{'content': 'A car travels 40 kph for 20 kilo...    math
# 5551      math8k  [{'content': 'What is the largest $n$ such tha...    math
#
# ...

# %%
test_df
# Out:
#     data_source                                             prompt ability  \
# 0         amc23  [{'content': 'Cities $A$ and $B$ are $45$ mile...    math
# 1         amc23  [{'content': 'Positive real numbers $x$ and $y...    math
# 2         amc23  [{'content': 'What is the degree measure of th...    math
# 3         amc23  [{'content': 'What is the value of
# \[2^3 - 1^3...    math
# 4         amc23  [{'content': 'In a table tennis tournament eve...    math
# ..          ...                                                ...     ...
# 655     math500  [{'content': 'What is the domain of the functi...    math
# 656     math500  [{'content': 'Let $z = 1+i$ and $w = \dfrac{3z...    math
# 657     math500  [{'content': 'An equiangular octagon has four ...    math
# 658     math500  [{'content': 'A sequence $(a_n)$ is defined as...    math
# 659     math500  [{'content': 'Altitudes $\overline{AD}$ and $\...    math
#
#                                           reward_model  \
# ...

# %%
export RAY_IP_ADDRESS="127.0.0.1"
export MY_RAY_PORT=6379
ray start --head --port $MY_RAY_PORT --node-ip-address=$RAY_IP_ADDRESS \
  --include-dashboard=False --num-gpus=2
export RAY_ADDRESS="$RAY_IP_ADDRESS:$MY_RAY_PORT"
trap "echo 'Shutting down Ray'; ray stop" EXIT

# %% [markdown]
# or can i open a worker on the remote gpu node and have a head on my local machine that connects to the gpu on that worker and i run the script on head so it can use the gpu but don't worry about ray cluster on the gpu node

# %%
export RAY_NODE_IP_ADDRESS="127.0.0.1"
export RAY_TMPDIR="/share/goyal/ray_tmp"
unset RAY_ADDRESS

# %% [markdown]
# ic i tried to the node ip address to be something else i.e. starting a new ray cluster and the system still forces me to use the

# %%
ray start --address='127.0.0.1:6379' --num-gpus=2

# %%
import ray
ray.init(
    num_gpus=0,
    _temp_dir='/scratch/al2644/ray_tmp',
    )

# %%
from transformers import AutoModelForCausalLM
path = "./global_step_1/actor"
step1_model = AutoModelForCausalLM.from_pretrained(path)

# %%
import torch
from torch.distributed.checkpoint import merge_state_dict

merge_state_dict(
    path      = "./global_step_2/actor",
    storage_type = "sharded",       
    dst_path  = "./global_step_2/actor/model.pt",
    dst_type  = "full",             
    offload_to_cpu = True,
)

# %%
python -m transformers.utils.consolidate_fsdp_shard_weights \
       --model_path /absolute/path/to/global_step_2/actor \
       --output      /absolute/path/to/global_step_2/actor \
       --safe_serialization \
       --max_shard_size 2GB
